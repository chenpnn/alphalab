# %%
from alphalab.performance.metrics import *
from alphalab.performance.summary import performance_summary

# %%
df_bench_price = pd.read_excel("data/全收益指数价格.xlsx", index_col=0, skiprows=1)
df_bench_ret = df_bench_price.pct_change().dropna()
df_bench_ret = df_bench_ret.loc[pd.to_datetime("2015-01-01"):pd.to_datetime("2026-04-30")]
df_bench_ret
# Out:
#                300收益     500收益     800收益      50收益    A100收益  中证A500全收益  \
# 2015-01-05  0.030516  0.017717  0.027343  0.026369  0.032351   0.029738
# 2015-01-06 -0.000132  0.011610  0.002752 -0.007637 -0.004834   0.006966
# 2015-01-07  0.000750  0.001529  0.000942  0.002217  0.000997  -0.000847
# 2015-01-08 -0.023199 -0.008054 -0.019455 -0.029267 -0.028026  -0.018381
# 2015-01-09 -0.003300 -0.006425 -0.004082  0.004755  0.000951  -0.003325
# ...              ...       ...       ...       ...       ...        ...
# 2026-04-24 -0.003513 -0.005706 -0.004139  0.005844  0.002392  -0.003481
# 2026-04-27  0.000331  0.006219  0.002011 -0.002034 -0.000400   0.002172
# 2026-04-28 -0.002629 -0.011415 -0.005147  0.003868 -0.003864  -0.005962
# 2026-04-29  0.011011  0.016929  0.012696  0.005790  0.014514   0.014160
# 2026-04-30 -0.000536  0.000958 -0.000109  0.006066  0.002452   0.001284
#
#             300质量全收益     300收价     300收成  300红利低波全收益  中证1000全收益  中证A50全收益  \
# ...

# %%
performance_summary(df_bench_ret)
# Out:
#                   开始日期        结束日期      区间收益     年化收益率     年化波动率      夏普比率  \
# 300收益       2015-01-05  2026-04-30  0.747411  0.052029  0.214294  0.242795
# 500收益       2015-01-05  2026-04-30    0.8095  0.055373  0.252616  0.219197
# 800收益       2015-01-05  2026-04-30  0.760763  0.052757    0.2179  0.242118
# 50收益        2015-01-05  2026-04-30   0.58781  0.042912  0.211167  0.203215
# A100收益      2015-01-05  2026-04-30  0.814502  0.055638  0.214543  0.259331
# 中证A500全收益   2015-01-05  2026-04-30  0.999582  0.064996  0.217922  0.298256
# 300质量全收益    2015-01-05  2026-04-30  1.509733  0.087218  0.199063  0.438143
# 300收价       2015-01-05  2026-04-30  1.041911  0.067026  0.203089  0.330031
# 300收成       2015-01-05  2026-04-30   0.89359  0.059738  0.237396   0.25164
# 300红利低波全收益  2015-01-05  2026-04-30  1.433254  0.084165  0.183127  0.459595
# 中证1000全收益   2015-01-05  2026-04-30  0.534901  0.039705  0.274402  0.144697
# ...
